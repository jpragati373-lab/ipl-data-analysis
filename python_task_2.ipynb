# %% [markdown]
# <a href="https://colab.research.google.com/github/jpragati373-lab/ipl-data-analysis/blob/main/python_task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ["Rahul", "Priya", "Aman", "Neha", "Riya"]

for name in students:
    print(name)
# Out:
# Rahul
# Priya
# Aman
# Neha
# Riya

# %%
numbers = [10, 20, 30, 40, 50]

print("First element:", numbers[0])
print("Last element:", numbers[-1])
# Out:
# First element: 10
# Last element: 50

# %%
fruits = ["Apple", "Banana", "Mango"]

fruits.append("Orange")

print("Updated List:", fruits)
# Out:
# Updated List: ['Apple', 'Banana', 'Mango', 'Orange']

# %%
subjects = ["Math", "Science", "English", "History"]

subjects.insert(2, "AI")

print("Updated List:", subjects)
# Out:
# Updated List: ['Math', 'Science', 'AI', 'English', 'History']

# %%
numbers = [10, 20, 30, 40, 50]

numbers.pop(2)

print("Updated List:", numbers)
# Out:
# Updated List: [10, 20, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Sum:", sum(numbers))
# Out:
# Length: 5
# Maximum: 50
# Minimum: 10
# Sum: 150

# %%
numbers = []

for i in range(5):
    num = int(input("Enter a number: "))
    numbers.append(num)

print("Complete List:", numbers)
# Out:
# Enter a number: 123
# Enter a number: 234
# Enter a number: 456
# Enter a number: 6789
# Enter a number: 675
# Complete List: [123, 234, 456, 6789, 675]

# %%
cities = ["Delhi", "Mumbai", "Chennai", "Kolkata"]

if "Delhi" in cities:
    print("Delhi exists in the list")
else:
    print("Delhi does not exist in the list")
# Out:
# Delhi exists in the list

# %%
colors = ("Red", "Blue", "Green", "Yellow", "Black")

for color in colors:
    print(color)
# Out:
# Red
# Blue
# Green
# Yellow
# Black

# %%
numbers = (10, 20, 30, 40, 50)

print("First element:", numbers[0])
print("Last element:", numbers[-1])
# Out:
# First element: 10
# Last element: 50

# %%
students = ("Rahul", "Priya", "Rahul", "Neha", "Rahul")

name = input("Enter name to count: ")

print("Count:", students.count(name))
# Out:
# Enter name to count: pragati
# Count: 0

# %%
numbers = (10, 20, 30, 40, 50)

print("Maximum value:", max(numbers))
print("Minimum value:", min(numbers))
print("Length of tuple:", len(numbers))
# Out:
# Maximum value: 50
# Minimum value: 10
# Length of tuple: 5

# %%
numbers = (10, 20, 30)

numbers[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_603/4002450567.py in <cell line: 0>()
#       1 numbers = (10, 20, 30)
#       2
# ----> 3 numbers[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (1, 2, 3, 4, 5)

lst = list(t)

print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
s = {10, 20, 30, 40, 50}

print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
s = {10, 20, 30}

s.add(40)

print(s)
# Out:
# {40, 10, 20, 30}

# %%
s = {10, 20, 30, 40}

s.remove(20)

print(s)
# Out:
# {40, 10, 30}

# %%
s = {10, 20, 30, 30, 40, 40}

print(s)
# Out:
# {40, 10, 20, 30}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A | B)
print("Intersection:", A & B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}

# %%
s = {10, 20, 30, 40, 50}

num = int(input("Enter a number: "))

if num in s:
    print("Number exists")
else:
    print("Number does not exist")
# Out:
# Enter a number: 657
# Number does not exist

# %%
student = {
    "Name": "Rahul",
    "Age": 20,
    "City": "Mumbai"
}

print(student.values())
# Out:
# dict_values(['Rahul', 20, 'Mumbai'])

# %%
student = {
    "name": "Siva",
    "age": 24
}

student["course"] = "Python"

print(student)
# Out:
# {'name': 'Siva', 'age': 24, 'course': 'Python'}

# %%
employee = {
    "id": 101,
    "name": "Ravi",
    "salary": 50000
}

print("Keys:", employee.keys())
print("Values:", employee.values())
# Out:
# Keys: dict_keys(['id', 'name', 'salary'])
# Values: dict_values([101, 'Ravi', 50000])

# %%
student = {
    "name": "Priya",
    "age": 20
}

student["age"] = 21

print(student)
# Out:
# {'name': 'Priya', 'age': 21}

# %%
person = {
    "name": "Test",
    "age": 24,
    "city": "Chennai"
}

person.pop("city")

print(person)
# Out:
# {'name': 'Test', 'age': 24}

# %%
students = {
    "Rahul": 85,
    "Priya": 90,
    "Aman": 78,
    "Neha": 88,
    "Riya": 92
}

for name in students.keys():
    print(name)
# Out:
# Rahul
# Priya
# Aman
# Neha
# Riya

# %%
products = {
    "Laptop": 50000,
    "Mobile": 20000,
    "Mouse": 500
}

item = input("Enter product name: ")

if item in products:
    print("Price:", products[item])
else:
    print("Product not found")
# Out:
# Enter product name: laptop
# Product not found

# %%
student = {
    "name": "Rahul",
    "age": 20
}

key = input("Enter key: ")

if key in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Enter key: name
# Key exists

# %%
students = ["Rahul", "Priya", "Aman", "Neha", "Riya"]

t = tuple(students)

print(t)
# Out:
# ('Rahul', 'Priya', 'Aman', 'Neha', 'Riya')

# %%
marks = {
    "Rahul": 85,
    "Priya": 72,
    "Aman": 90,
    "Neha": 65,
    "Riya": 95
}

for name, score in marks.items():
    if score > 80:
        print(name, score)
# Out:
# Rahul 85
# Aman 90
# Riya 95
