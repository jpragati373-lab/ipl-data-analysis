# %% [markdown]
# <a href="https://colab.research.google.com/github/jpragati373-lab/ipl-data-analysis/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name = input("Enter student name: ")

print("Uppercase Name:", student_name.upper())
# Out:
# Enter student name: pragati
# Uppercase Name: PRAGATI

# %%
city_name = input("Enter city name: ")

print("Original Name:", city_name)
print("Uppercase:", city_name.upper())
print("Lowercase:", city_name.lower())
print("Title Case:", city_name.title())
# Out:
# Enter city name: berhampur
# Original Name: berhampur
# Uppercase: BERHAMPUR
# Lowercase: berhampur
# Title Case: Berhampur

# %%
text = input("Enter a string: ")

print("Total Length:", len(text))
# Out:
# Enter a string: tree
# Total Length: 4

# %%
text = input("Enter a string: ")

print("First Character:", text[0])
print("Last Character:", text[-1])
# Out:
# Enter a string: giant]
# First Character: g
# Last Character: ]

# %%
text = input("Enter a string: ")

count_a = text.count('a')

print("Number of 'a' =", count_a)
# Out:
# Enter a string: compassion
# Number of 'a' = 1

# %%
sentence = input("Enter a sentence: ")

new_sentence = sentence.replace("Python", "AI")

print("Modified Sentence:", new_sentence)
# Out:
# Enter a sentence: python
# Modified Sentence: python

# %%
email_address = input("Enter email address: ")

if email_address.endswith("@gmail.com"):
    print("Valid Gmail Address")
else:
    print("Not a Gmail Address")
# Out:
# Enter email address: j.pragati373@gmail.com
# Valid Gmail Address

# %%
user_input = input("Enter input: ")

if user_input.isdigit():
    print("Contains only digits")
else:
    print("Does not contain only digits")
# Out:
# Enter input: 23456
# Contains only digits

# %%
user_input = input("Enter input: ")

if user_input.isalpha():
    print("Contains only alphabets")
else:
    print("Does not contain only alphabets")
# Out:
# Enter input: pragati
# Contains only alphabets

# %%
fruit_string = "Apple,Mango,Banana,Orange"

fruit_list = fruit_string.split(",")

print(fruit_list)
# Out:
# ['Apple', 'Mango', 'Banana', 'Orange']

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")
# Out:
# Enter age: 22
# Eligible to Vote

# %%
number = float(input("Enter a number: "))

if number > 0:
    print("Positive Number")
elif number < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number: 90
# Positive Number

# %%
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))

if first_number > second_number:
    print("Greater Number:", first_number)
else:
    print("Greater Number:", second_number)
# Out:
# Enter first number: 456
# Enter second number: 789
# Greater Number: 789.0

# %%
marks = int(input("Enter marks: "))

if 90 <= marks <= 100:
    print("Grade A")
elif 75 <= marks <= 89:
    print("Grade B")
elif 50 <= marks <= 74:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 78
# Grade B

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 76
# Even Number

# %%
password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password: pragati@1223
# Strong Password

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 2026
# Not a Leap Year

# %%
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))
third_number = float(input("Enter third number: "))

largest_number = max(first_number, second_number, third_number)

print("Largest Number:", largest_number)
# Out:
# Enter first number: 23
# Enter second number: 32
# Enter third number: 45
# Largest Number: 45.0

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: pragati
# Enter password: pragati123
# Invalid Credentials

# %%
first_number = float(input("Enter first number: "))
second_number = float(input("Enter second number: "))
operator = input("Enter operator (+, -, *, /): ")

if operator == "+":
    result = first_number + second_number
elif operator == "-":
    result = first_number - second_number
elif operator == "*":
    result = first_number * second_number
elif operator == "/":
    if second_number != 0:
        result = first_number / second_number
    else:
        result = "Division by zero is not allowed"
else:
    result = "Invalid Operator"

print("Result:", result)
# Out:
# Enter first number: 34
# Enter second number: 43
# Enter operator (+, -, *, /): +
# Result: 77.0
